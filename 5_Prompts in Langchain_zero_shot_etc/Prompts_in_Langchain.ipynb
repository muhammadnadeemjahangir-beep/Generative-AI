# %%
pip install -qU langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.3 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

# Store once in Colab secrets (recommended)
os.environ["GROQ_API_KEY"] = userdata.get("Groq_API")

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate([
    ('system', 'You are a helpful {domain} expert'),
    ('human', 'Explain in simple terms, what is {topic}')
])

prompt = chat_template.invoke({'domain':'cricket','topic':'Dusra'})

print(prompt.messages)
# Out:
# [SystemMessage(content='You are a helpful cricket expert', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain in simple terms, what is Dusra', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# **Zero-shot prompt**

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.5
)

# Zero-shot prompt
zero_shot = "Write a professional email expressing interest in the AI Engineer position at Samsung."

# Generate response
response = model.invoke(zero_shot)

print(response.content)
# Out:
# Subject: Application for AI Engineer Position at Samsung
#
# Dear Hiring Manager,
#
# I am writing to express my strong interest in the AI Engineer position currently available at Samsung. As a highly motivated and experienced AI professional, I am confident that my skills and expertise align with the company's vision and goals.
#
# With [number] years of experience in AI engineering, I have developed a strong foundation in machine learning, deep learning, and computer vision. My expertise includes designing and implementing AI models, developing predictive analytics solutions, and integrating AI into various applications. I am well-versed in programming languages such as Python, Java, and C++, and have experience working with popular AI frameworks such as TensorFlow and PyTorch.
#
# I am particularly drawn to Samsung's commitment to innovation and its focus on developing cutting-edge AI technologies. I am impressed by the company's efforts to integrate AI into various product lines, including smartphones, home appliances, and automotive systems. I am excited about the prospect of contributing to the development of AI-powered solutions that can transform industries and improve people's lives.
#
# In addition to my technical skills, I possess excellent communication and collaboration skills, which have been essential in my previous roles. I have a proven track record of working effectively with cross-functional teams, including software engineers, data scientists, and product managers.
#
# I have attached my resume and a cover letter, which provide more details about my experience and qualifications. I would be thrilled to discuss my application and how I can contribute to Samsung's AI engineering team.
#
# Thank you for considering my application. I look forward to the opportunity to discuss this position further.
#
# Sincerely,
#
# [Your Name]
#
# Attachments: Resume, Cover Letter
#
# Note: Make sure to customize the email by using the job description and requirements provided by Samsung, and by highlighting your relevant skills and experiences. Also, proofread the email for grammar and spelling errors before sending it.

# %% [markdown]
# **few_shot_prompt**

# %%
few_shot_prompt = """
Example 1:
Subject: Excited to Apply for AI Engineer Role at Samsung
Hi Hiring Manager,
I am excited to apply for the AI Engineer position at Samsung. With expertise in AI and ML, I believe I can contribute significantly. Looking forward to the opportunity.
Best,
John Doe


Now, write a similar email for a Data Scientist role at Google.
"""

response = model.invoke(few_shot_prompt)
print(response.content)
# Out:
# Example 2:
# Subject: Application for Data Scientist Role at Google
# Hi Hiring Manager,
# I am thrilled to apply for the Data Scientist position at Google. With a strong background in data analysis, machine learning, and statistical modeling, I am confident in my ability to drive business insights and inform data-driven decisions. I am excited about the opportunity to contribute to Google's innovative culture and work with a talented team.
# Best,
# [Your Name]

# %% [markdown]
# **Chain-of-Thought (CoT)**

# %%
# Chain-of-Thought (CoT)
# Encourages the model to think step-by-step.
cot_prompt = """
Think step by step and explain your reasoning clearly.

Q1: A bakery bakes 120 cupcakes daily. If each customer buys 4 cupcakes, how many customers can be served in a day?

Q2: If the bakery increases production by 50%, how many total cupcakes will they bake per day?

Q3: Now, if each cupcake costs $2 and a customer buys 6 cupcakes, how much will the customer pay?

Q4: Assume the bakery spends $0.50 per cupcake on ingredients. If they bake 180 cupcakes in a day, what is their total cost for ingredients?
"""

# Invoke the model
response = model.invoke(cot_prompt)
print(response.content)
# Out:
# I'll answer each question step by step.
#
# **Q1: A bakery bakes 120 cupcakes daily. If each customer buys 4 cupcakes, how many customers can be served in a day?**
#
# To find the number of customers, we need to divide the total number of cupcakes by the number of cupcakes each customer buys.
#
# Number of cupcakes: 120
# Number of cupcakes per customer: 4
#
# Number of customers = Total number of cupcakes / Number of cupcakes per customer
# = 120 / 4
# = 30
#
# So, the bakery can serve 30 customers in a day.
#
# **Q2: If the bakery increases production by 50%, how many total cupcakes will they bake per day?**
#
# To find the new production, we need to increase the original production by 50%.
#
# Original production: 120 cupcakes
# Increase: 50% of 120 = 0.5 * 120 = 60
# New production: Original production + Increase
# = 120 + 60
# = 180
#
# So, the bakery will bake 180 cupcakes per day after increasing production by 50%.
#
# **Q3: Now, if each cupcake costs $2 and a customer buys 6 cupcakes, how much will the customer pay?**
#
# To find the total cost for the customer, we need to multiply the cost of each cupcake by the number of cupcakes the customer buys.
#
# Cost per cupcake: $2
# Number of cupcakes per customer: 6
#
# Total cost for the customer = Cost per cupcake * Number of cupcakes per customer
# = $2 * 6
# = $12
#
# So, the customer will pay $12.
#
# **Q4: Assume the bakery spends $0.50 per cupcake on ingredients. If they bake 180 cupcakes in a day, what is their total cost for ingredients?**
#
# To find the total cost for ingredients, we need to multiply the cost per cupcake by the total number of cupcakes.
#
# Cost per cupcake: $0.50
# Total number of cupcakes: 180
#
# Total cost for ingredients = Cost per cupcake * Total number of cupcakes
# = $0.50 * 180
# = $90
#
# So, the bakery's total cost for ingredients is $90.

# %% [markdown]
# **Instruction based Prompt**

# %%
# Gives explicit instructions to control response format.

instruction_prompt = """
Write a short, enthusiastic email (max 4 lines) applying for the AI Engineer role at Samsung. Highlight AI skills.
"""
response = model.invoke(instruction_prompt)
print(response.content)
# Out:
# Subject: Application for AI Engineer Role at Samsung
#
# Dear Hiring Team,
#
# I am thrilled to apply for the AI Engineer position at Samsung, where I can leverage my expertise in machine learning, deep learning, and natural language processing to drive innovation. With a strong background in AI development and a passion for cutting-edge technology, I am confident in my ability to make a meaningful contribution to your team. My proficiency in Python, TensorFlow, and PyTorch will enable me to hit the ground running and deliver high-quality solutions. I look forward to discussing my application.
#
# Best regards,
# [Your Name]

# %% [markdown]
# **Role based Prompt**

# %%
# Assigns a role to the model to influence its response style.
role_based_prompt = """
You are an expert AI recruiter. Write a compelling email to Samsung about my interest in the AI Engineer position.
"""

response = model.invoke(role_based_prompt)
print(response.content)
# Out:
# Here's a compelling email to Samsung about your interest in the AI Engineer position:
#
# Subject: Application for AI Engineer Position at Samsung
#
# Dear Hiring Manager,
#
# I am writing to express my strong interest in the AI Engineer position currently available at Samsung. As a highly motivated and experienced AI professional, I am confident that my skills and passion for innovation would make me a valuable asset to your team.
#
# With [number] years of experience in developing and deploying AI solutions, I possess a deep understanding of machine learning algorithms, deep learning techniques, and large-scale data processing. My expertise spans a wide range of areas, including computer vision, natural language processing, and predictive analytics. I am well-versed in various programming languages, including Python, Java, and C++, and have experience with popular AI frameworks such as TensorFlow and PyTorch.
#
# What draws me to Samsung is the company's commitment to pushing the boundaries of innovation and its dedication to using AI to improve people's lives. I am impressed by the company's efforts in developing cutting-edge AI technologies, such as [specific Samsung AI project or initiative], and I am excited about the prospect of contributing to such a forward-thinking organization.
#
# As a seasoned AI engineer, I have a proven track record of delivering high-quality solutions that meet and exceed expectations. My strengths include:
#
# * Strong technical skills in AI and machine learning
# * Excellent problem-solving and analytical skills
# * Proven ability to work effectively in cross-functional teams
# * Strong communication and collaboration skills
# * Experience with agile development methodologies and version control systems
#
# I am particularly drawn to Samsung's emphasis on [specific aspect of Samsung's culture or values that resonates with you]. As someone who is passionate about using AI to drive positive change, I believe that I would thrive in an environment that values innovation, collaboration, and customer-centricity.
#
# I would welcome the opportunity to discuss my qualifications further and explore how my skills and experience align with the requirements of the AI Engineer position. Please feel free to contact me at [your email address] or [your phone number].
#
# Thank you for considering my application. I look forward to the opportunity to contribute to Samsung's mission to "Inspire the World, Create the Future."
#
# Sincerely,
#
# [Your Name]

# %% [markdown]
# **Prompt Template**

# %%
template = "Write a {tone} email to {company} expressing interest in the {position} position, mentioning {skill} as a key strength. Keep it to 4 lines max"

prompt_template = ChatPromptTemplate.from_template(template)

prompt =  prompt_template.invoke({
"tone": "energetic",
"company": "samsung",
"position": "AI Engineer",
"skill": "AI"
})
result = model.invoke(prompt)
print(f"Answer from Google: {result.content}")
# Out:
# Answer from Google: Subject: Excited to Join Samsung as an AI Engineer
#
# Dear Samsung Recruitment Team,
#
# I'm thrilled to express my enthusiasm for the AI Engineer position at Samsung, where I can leverage my passion for Artificial Intelligence to drive innovation and push boundaries. My expertise in AI is a key strength, and I'm confident it will be a valuable asset to your team. I'd love to discuss how my skills can contribute to Samsung's mission. Please find my resume attached for your review.
#
# Best regards,
# [Your Name]
