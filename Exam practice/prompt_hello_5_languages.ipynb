# %%
# %pip install -qU langchain langchain-core langchain-groq gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 803.1 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 9.1 MB/s eta 0:00:00

# %%
import os

try:
    from google.colab import userdata
    groq_api_key = userdata.get("GROQ_API_KEY") or userdata.get("GROQ_API_KEY")
except Exception:
    groq_api_key = None

if groq_api_key:
    os.environ["GROQ_API_KEY"] = groq_api_key
    print("Groq API key configured successfully.")
else:
    raise ValueError("GROQ_API_KEY not found in Colab Secrets.")
# Out:
# Groq API key configured successfully.

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0,
    max_tokens=300
)

# %%
from langchain_core.prompts import PromptTemplate

template = PromptTemplate(
    template="Greet this person in 5 languages. The name of the person is {name}.",
    input_variables=["name"]
)

prompt = template.invoke({"name": "Nadeem"})
result = model.invoke(prompt)

print(result.content)
# Out:
# Sure! Here are friendly greetings for **Nadeem** in five different languages:
#
# | Language | Greeting |
# |----------|----------|
# | **English** | Hello, Nadeem! |
# | **Spanish** | ¡Hola, Nadeem! |
# | **French** | Bonjour, Nadeem ! |
# | **Arabic** | مرحبًا يا نديم! (Marḥabān yā Nadeem!) |
# | **Urdu** | سلام ندیم! (Salām Nadeem!) |
#
# Hope you enjoy the multilingual welcome!
