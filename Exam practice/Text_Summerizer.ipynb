# %%
# !pip install -q groq gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.1 MB/s eta 0:00:00

# %%
import getpass
from groq import Groq
import gradio as gr

# Enter your Groq API key
api_key = getpass.getpass("Enter your Groq API key: ")

# Create Groq client
client = Groq(api_key=api_key)


# Summarization function
def summarize_text(text):

    if not text or not text.strip():
        return "Please enter some text."

    try:
        response = client.chat.completions.create(
            model="openai/gpt-oss-120b",
            messages=[
                {
                    "role": "system",
                    "content": "You are an expert text summarizer."
                },
                {
                    "role": "user",
                    "content": f"""
                    Summarize the following text in clear 5 bullet points.

Text:
{text}
"""
                }
            ],
            temperature=0.3,
            max_tokens=300
        )

        return response.choices[0].message.content

    except Exception as e:
        return f"Error: {str(e)}"


# Create Gradio interface
demo = gr.Interface(
    fn=summarize_text,
    inputs=gr.Textbox(
        lines=10,
        placeholder="Paste a long paragraph here...",
        label="Text to Summarize"
    ),
    outputs=gr.Textbox(
        label="Summary",
        lines=10
    ),
    title="📄 AI Text Summarizer",
    description="Summarize long text using the Groq API and Llama 3.3.",
)


# Launch the application
demo.launch()
# Out:
# Enter your Groq API key: ··········
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://19b84b3a94de1bd9d2.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://19b84b3a94de1bd9d2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
